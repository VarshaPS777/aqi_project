# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('GAQI.csv')
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.head(11)
# Out:
#                      timestamp country      city  latitude  longitude    pm25  \
# 0   2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1   2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2   2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3   2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4   2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5   2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
# 6   2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
# 7   2025-11-05 01:25:17.554219      US  New York    40.713    -74.006  57.816
# 8   2025-11-05 02:25:17.554219      US  New York    40.713    -74.006  60.914
# 9   2025-11-05 03:25:17.554219      US  New York    40.713    -74.006  16.464
# 10  2025-11-05 04:25:17.554219      US  New York    40.713    -74.006  48.469
#
# ...

# %%
df.tail(11)
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17989  2025-11-19 07:25:17.554219      CH  Zurich    47.377      8.542
# 17990  2025-11-19 08:25:17.554219      CH  Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH  Zurich    47.377      8.542
# 17992  2025-11-19 10:25:17.554219      CH  Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH  Zurich    47.377      8.542
# 17994  2025-11-19 12:25:17.554219      CH  Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.shape
# Out:
# (18000, 15)

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# timestamp      0
# country        0
# city           0
# latitude       0
# longitude      0
# pm25           0
# pm10           0
# no2            0
# so2            0
# o3             0
# co             0
# aqi            0
# temperature    0
# humidity       0
# wind_speed     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df.dtypes
# Out:
# timestamp       object
# country         object
# city            object
# latitude       float64
# longitude      float64
# pm25           float64
# pm10           float64
# no2            float64
# so2            float64
# o3             float64
# co             float64
# aqi              int64
# temperature    float64
# humidity       float64
# wind_speed     float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#              latitude  longitude      pm25      pm10       no2       so2  \
# latitude     1.000000  -0.326934  0.000071  0.002831 -0.001264 -0.008259
# longitude   -0.326934   1.000000 -0.002588 -0.013217  0.007569  0.012564
# pm25         0.000071  -0.002588  1.000000 -0.005904 -0.002220  0.000701
# pm10         0.002831  -0.013217 -0.005904  1.000000 -0.003896 -0.008034
# no2         -0.001264   0.007569 -0.002220 -0.003896  1.000000  0.006108
# so2         -0.008259   0.012564  0.000701 -0.008034  0.006108  1.000000
# o3          -0.000654   0.000283  0.011293 -0.003277 -0.001936 -0.007127
# co          -0.003521   0.004280  0.006617  0.001398 -0.009992 -0.015675
# aqi         -0.001187  -0.008687  0.556094  0.207499  0.531731 -0.005202
# temperature  0.008167  -0.010885 -0.005003  0.012491  0.011003 -0.004727
# humidity    -0.005283   0.006083  0.004710 -0.001294 -0.003373  0.008162
# wind_speed   0.000570   0.003305 -0.006191  0.002896 -0.000878 -0.006751
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
df.drop(['timestamp','city','latitude','longitude'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#   country    pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# 0      US  50.295  108.938  27.998  6.539  52.568  1.096  108       18.504
# 1      US  32.083   63.043  36.120  4.021  43.536  1.075   90        5.838
# 2      US  42.250   82.553  26.935  9.538  23.320  0.977   84       31.833
# 3      US  30.403   79.951  63.536  7.609  31.369  0.230  158       23.140
# 4      US  21.083   66.423  38.997  6.919  45.615  1.085   97       13.632
# 5      US  31.242   92.779  30.633  8.030  43.725  0.347   92       15.159
# 6      US  77.690   65.198  20.302  7.641  62.687  0.734  155       36.729
# 7      US  57.816  111.709  34.533  6.945  41.304  0.771  115       37.891
# 8      US  60.914   44.775  40.936  6.779  36.751  1.014  121       24.092
# 9      US  16.464   76.631  28.119  8.561  79.467  1.081   76       11.490
#
#    humidity  wind_speed
# 0    70.168       3.725
# 1    80.088       8.969
# 2    62.783       9.650
# 3    89.153       8.956
# ...

# %%
df.tail(10)
# Out:
#       country    pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17990      CH  29.621  27.051  13.218  9.936  49.502  0.678   59       32.144
# 17991      CH  52.120  71.160  35.405  7.752  39.811  0.878  104       32.556
# 17992      CH  44.086  87.359  36.588  4.897  50.972  1.191   91       14.728
# 17993      CH  76.613  37.495  29.662  5.419  57.042  1.103  153       20.437
# 17994      CH  42.982  54.692  37.756  7.528  55.321  0.929   94       35.439
# 17995      CH  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996      CH   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997      CH  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998      CH  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999      CH  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17990    67.180       6.809
# 17991    31.372       2.787
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df['country'].value_counts()
# Out:
# country
# US    1800
# IN    1800
# CN     720
# JP     720
# CA     720
# AU     720
# IT     360
# ES     360
# DE     360
# FR     360
# GB     360
# ZA     360
# BR     360
# MX     360
# NG     360
# KE     360
# EG     360
# AE     360
# QA     360
# SA     360
# KR     360
# AR     360
# HK     360
# SG     360
# MY     360
# TH     360
# ID     360
# NZ     360
# RU     360
# TR     360
# IR     360
# PK     360
# PH     360
# VN     360
# PL     360
# SE     360
# FI     360
# CH     360
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['aqi'], bins=30, kde=True, color='purple')
plt.title('Distribution of AQI Values')
plt.xlabel('AQI')
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.subplot(1, 3, 1)
sns.scatterplot(x=df['pm25'], y=df['aqi'], alpha=0.5)
plt.title('PM2.5 vs AQI')
# Out:
# Text(0.5, 1.0, 'PM2.5 vs AQI')

# %%
plt.subplot(1,2,2)
sns.scatterplot(x=df['no2'], y=df['aqi'], alpha=0.5)
plt.title('NO2 vs AQI')
# Out:
# Text(0.5, 1.0, 'NO2 vs AQI')

# %%
plt.subplot(1, 3, 3)
sns.scatterplot(x=df['o3'], y=df['aqi'], alpha=0.5)
plt.title('O3 vs AQI')
plt.show()

# %%
x = df.drop(['aqi'],axis=1)
y = df.aqi.values
y
feature=x

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
data=make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['country']),remainder='passthrough')
x=data.fit_transform(x)
x
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 179999 stored elements and shape (18000, 47)>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([119.,  81.,  72., ...,  93., 113.,  69.], shape=(3600,))

# %%
y_test
# Out:
# array([119,  81,  72, ...,  93, 113,  69], shape=(3600,))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,mean_absolute_percentage_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.08361111111111111

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.38916666666666666

# %%
rmse=root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 0.6238322424070967

# %%
mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.0010274527234944181

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.999343738376895

# %%
import joblib
joblib.dump(model,'model.joblib')
joblib.dump(data,'encoder.joblib')
joblib.dump(feature,'feature.joblib')
feature.columns
# Out:
# Index(['country', 'pm25', 'pm10', 'no2', 'so2', 'o3', 'co', 'temperature',
#        'humidity', 'wind_speed'],
#       dtype='object')
